# %%
import SalesAnalysis_Utils as utils

import pandas as pd
import numpy as np
import sys
import os
import os.path
from os import path
import shutil
import datetime
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn import datasets, ensemble
from sklearn.inspection import permutation_importance
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline

# %%
FILE_PATH = "Updated_sales.csv"
CHUNK_SIZE = 1000

df = utils.read_raw_data(file_path=FILE_PATH)
# Out:
# /Users/alexandermendelsohn/anaconda3/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)

# %%
processed_df = (
    df
    .pipe(utils.split_purchase_address)
    .pipe(utils.split_order_date)
    .pipe(utils.convert_numerical_column_types)
    .pipe(utils.calculate_total_order_cost)
)

# %%
processed_df.describe()
# Out:
#             Order ID  Quantity Ordered     Price Each    Order Month  \
# count  185686.000000     185686.000000  185686.000000  185686.000000
# mean   230411.376227          1.124544     184.519255       7.058653
# std     51511.717183          0.443069     332.843838       3.502932
# min    141234.000000          1.000000       2.990000       1.000000
# 25%    185833.250000          1.000000      11.950000       4.000000
# 50%    230354.500000          1.000000      14.950000       7.000000
# 75%    275028.750000          1.000000     150.000000      10.000000
# max    319670.000000          9.000000    1700.000000      12.000000
#
#            Order Day     Order Hour     Order Year     Total Cost
# count  185686.000000  185686.000000  185686.000000  185686.000000
# mean       15.758662      14.412934    2019.000183     185.611936
# std         8.782064       5.423329       0.013530     333.032118
# min         1.000000       0.000000    2019.000000       2.990000
# 25%         8.000000      11.000000    2019.000000      11.950000
# 50%        16.000000      15.000000    2019.000000      14.950000
# 75%        23.000000      19.000000    2019.000000     150.000000
# max        31.000000      23.000000    2020.000000    3400.000000

# %%
response = 'Total Cost'

# %%
sns.FacetGrid(processed_df
              #, hue = "survival_status"
             ).map(sns.histplot, "Price Each").add_legend()
plt.show()

# %%
sns.FacetGrid(processed_df
              #, hue = "survival_status"
             ).map(sns.displot, "Price Each").add_legend()
plt.show()
# Out:
# /Users/alexandermendelsohn/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:2142: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize = (15, 4))
sns.violinplot(x = 'Order Hour', y = 'Quantity Ordered', data = processed_df)
plt.show()

# %%
sns.jointplot(x = "Total Cost", y = 'Quantity Ordered', data = processed_df)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-09e61463464e> in <module>
# ----> 1 sns.jointplot(x = "Total Cost", y = 'Quantity Ordered', data = processed_df)
#       2 plt.show()
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2243         palette=palette, hue_order=hue_order, hue_norm=hue_norm,
#    2244         dropna=dropna, height=height, ratio=ratio, space=space,
# -> 2245         xlim=xlim, ylim=ylim, marginal_ticks=marginal_ticks,
#    2246     )
#    2247
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py in __init__(self, data, x, y, hue, height, ratio, space, palette, hue_order, hue_norm, dropna, xlim, ylim, marginal_ticks)
#    1720
#    1721         # Process the input variables
# -> 1722         p = VectorPlotter(data=data, variables=dict(x=x, y=y, hue=hue))
#    1723         plot_data = p.plot_data.loc[:, p.plot_data.notna().any()]
#    1724
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/_oldcore.py in __init__(self, data, variables)
#     638         # information for numeric axes would be information about log scales.
#     639         self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 640         self.assign_variables(data, variables)
#     641
#     642         for var, cls in self._semantic_mappings.items():
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/_oldcore.py in assign_variables(self, data, variables)
#     700             self.input_format = "long"
#     701             plot_data, variables = self._assign_variables_longform(
# --> 702                 data, **variables,
#     703             )
#     704
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/_oldcore.py in _assign_variables_longform(self, data, **kwargs)
#     960         # Construct a tidy plot DataFrame. This will convert a number of
#     961         # types automatically, aligning on index in case of pandas objects
# --> 962         plot_data = pd.DataFrame(plot_data)
#     963
#     964         # Reduce the variables dictionary to fields with valid data
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
#     256
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      67
#      68     # don't force copy because getting jammed in an ndarray anyway
# ---> 69     arrays = _homogenize(arrays, index, dtype)
#      70
#      71     # from BlockManager perspective
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in _homogenize(data, index, dtype)
#     321                 val = lib.fast_multiget(val, oindex.values, default=np.nan)
#     322             val = sanitize_array(
# --> 323                 val, index, dtype=dtype, copy=False, raise_cast_failure=False
#     324             )
#     325
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     463                 value = maybe_cast_to_datetime(value, dtype)
#     464
# --> 465             subarr = construct_1d_arraylike_from_scalar(value, len(index), dtype)
#     466
#     467         else:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in construct_1d_arraylike_from_scalar(value, length, dtype)
#    1450                 value = ensure_str(value)
#    1451
# -> 1452         subarr = np.empty(length, dtype=dtype)
#    1453         subarr.fill(value)
#    1454
#
# TypeError: Cannot interpret '<attribute 'dtype' of 'numpy.generic' objects>' as a data type

# %%
# pie charts 

for v in [column.value for column in utils.CategoricalColumns]:
    df_sum_tmp = processed_df.groupby(v).agg({response: ['mean', 'sum', 'std', 'count']})
    df_sum_tmp.columns = df_sum_tmp.columns.droplevel()
    df_sum_tmp = df_sum_tmp.rename(columns={"count": v})
    ax = df_sum_tmp.plot.pie(y=v, figsize=(8,8), legend = True,  labels= None, textprops={'fontsize': 12})

# %%
# count plots

for v in [column.value for column in utils.CategoricalColumns]:
    fig, ax = plt.subplots(figsize=(8,8))
    sns.set(font_scale = 1)
    #ax = sns.boxplot(x=v, y="response, data=df)
    ax = sns.countplot(x=v, data=processed_df)
    _ = ax.set_xticklabels(ax.get_xticklabels(),rotation=90)

# %%
# histograms 

#from matplotlib import pyplot as plt
#for v in [column.value for column in utils.NumericalColumns]:
#    df_tmp = processed_df[[response,v]].dropna()
#    fig, ax = plt.subplots(figsize=(10,8))
#    sns.set(font_scale = 2)
#    ax = sns.histplot(data=df_tmp, x=v, bins = 10)

# %%
processed_df.corr()
# Out:
#                   Order ID  Quantity Ordered  Price Each  Order Month  \
# Order ID          1.000000          0.000739   -0.002854     0.993061
# Quantity Ordered  0.000739          1.000000   -0.148422     0.000831
# Price Each       -0.002854         -0.148422    1.000000    -0.003364
# Order Month       0.993061          0.000831   -0.003364     1.000000
# Order Day         0.016123          0.001243   -0.002833     0.016232
# Order Hour        0.001232         -0.002211    0.001736     0.001786
# Order Year        0.020146          0.002484    0.002666    -0.023406
# Total Cost       -0.002946         -0.139564    0.999202    -0.003454
#
#                   Order Day  Order Hour  Order Year  Total Cost
# Order ID           0.016123    0.001232    0.020146   -0.002946
# Quantity Ordered   0.001243   -0.002211    0.002484   -0.139564
# Price Each        -0.002833    0.001736    0.002666    0.999202
# Order Month        0.016232    0.001786   -0.023406   -0.003454
# Order Day          1.000000   -0.002806   -0.022743   -0.002695
# Order Hour        -0.002806    1.000000   -0.032148    0.001683
# Order Year        -0.022743   -0.032148    1.000000    0.002820
# Total Cost        -0.002695    0.001683    0.002820    1.000000

# %%
plt.figure(figsize = (20, 20))
sns.set(font_scale = 2)
sns.heatmap(processed_df.corr(), annot = True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,15))   
sns.set(font_scale=1.5)
sns.heatmap(processed_df.drop(["Order ID","Order Year"], axis=1).corr(), annot=True, fmt=".1%", ax=ax, cmap=sns.color_palette("RdYlGn_r", as_cmap=True))

# %%
sns.jointplot(x = 'Total Cost',  y = 'Price Each' , data = processed_df,  kind = 'kde', fill = True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-aaf584c1689c> in <module>
# ----> 1 sns.jointplot(x = 'Total Cost',  y = 'Price Each' , data = processed_df,  kind = 'kde', fill = True)
#       2 plt.show()
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2243         palette=palette, hue_order=hue_order, hue_norm=hue_norm,
#    2244         dropna=dropna, height=height, ratio=ratio, space=space,
# -> 2245         xlim=xlim, ylim=ylim, marginal_ticks=marginal_ticks,
#    2246     )
#    2247
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py in __init__(self, data, x, y, hue, height, ratio, space, palette, hue_order, hue_norm, dropna, xlim, ylim, marginal_ticks)
#    1720
#    1721         # Process the input variables
# -> 1722         p = VectorPlotter(data=data, variables=dict(x=x, y=y, hue=hue))
#    1723         plot_data = p.plot_data.loc[:, p.plot_data.notna().any()]
#    1724
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/_oldcore.py in __init__(self, data, variables)
#     638         # information for numeric axes would be information about log scales.
#     639         self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 640         self.assign_variables(data, variables)
#     641
#     642         for var, cls in self._semantic_mappings.items():
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/_oldcore.py in assign_variables(self, data, variables)
#     700             self.input_format = "long"
#     701             plot_data, variables = self._assign_variables_longform(
# --> 702                 data, **variables,
#     703             )
#     704
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/_oldcore.py in _assign_variables_longform(self, data, **kwargs)
#     960         # Construct a tidy plot DataFrame. This will convert a number of
#     961         # types automatically, aligning on index in case of pandas objects
# --> 962         plot_data = pd.DataFrame(plot_data)
#     963
#     964         # Reduce the variables dictionary to fields with valid data
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
#     256
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      67
#      68     # don't force copy because getting jammed in an ndarray anyway
# ---> 69     arrays = _homogenize(arrays, index, dtype)
#      70
#      71     # from BlockManager perspective
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in _homogenize(data, index, dtype)
#     321                 val = lib.fast_multiget(val, oindex.values, default=np.nan)
#     322             val = sanitize_array(
# --> 323                 val, index, dtype=dtype, copy=False, raise_cast_failure=False
#     324             )
#     325
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     463                 value = maybe_cast_to_datetime(value, dtype)
#     464
# --> 465             subarr = construct_1d_arraylike_from_scalar(value, len(index), dtype)
#     466
#     467         else:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in construct_1d_arraylike_from_scalar(value, length, dtype)
#    1450                 value = ensure_str(value)
#    1451
# -> 1452         subarr = np.empty(length, dtype=dtype)
#    1453         subarr.fill(value)
#    1454
#
# TypeError: Cannot interpret '<attribute 'dtype' of 'numpy.generic' objects>' as a data type
